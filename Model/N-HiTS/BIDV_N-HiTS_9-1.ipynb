# %%
#| default_exp models.nhits

# %%
#| hide
# %load_ext autoreload
# %autoreload 2

# %%
# Initial
DATASET_NAME = 'BIDV'
DATASET_LABEL = 'BIDV'
TEST_RATIO = 0.1
TRAIN_TEST_LABEL = f'{(1 - TEST_RATIO) * 10:.0f}-{TEST_RATIO * 10:.0f}'

DAY_TO_PREDICT = 90

# %% [markdown]
# # NHITS

# %% [markdown]
# Long-horizon forecasting is challenging because of the *volatility* of the predictions and the *computational complexity*. To solve this problem we created the Neural Hierarchical Interpolation for Time Series (NHITS). `NHITS` builds upon `NBEATS` and specializes its partial outputs in the different frequencies of the time series through hierarchical interpolation and multi-rate input
# processing. On the long-horizon forecasting task `NHITS` improved accuracy by 25% on AAAI's best paper award the `Informer`, while being 50x faster.
#
# The model is composed of several MLPs with ReLU non-linearities. Blocks are connected via doubly residual stacking principle with the backcast $\mathbf{\tilde{y}}_{t-L:t,l}$ and forecast $\mathbf{\hat{y}}_{t+1:t+H,l}$ outputs of the l-th block. Multi-rate input pooling, hierarchical interpolation and backcast residual connections together induce the specialization of the additive predictions in different signal bands, reducing memory footprint and computational time, thus improving the architecture parsimony and accuracy.
#
# **References**<br>
# -[Boris N. Oreshkin, Dmitri Carpov, Nicolas Chapados, Yoshua Bengio (2019). "N-BEATS: Neural basis expansion analysis for interpretable time series forecasting".](https://arxiv.org/abs/1905.10437)<br>
# -[Cristian Challu, Kin G. Olivares, Boris N. Oreshkin, Federico Garza, Max Mergenthaler-Canseco, Artur Dubrawski (2023). "NHITS: Neural Hierarchical Interpolation for Time Series Forecasting". Accepted at the Thirty-Seventh AAAI Conference on Artificial Intelligence.](https://arxiv.org/abs/2201.12886)<br>
# -[Zhou, H.; Zhang, S.; Peng, J.; Zhang, S.; Li, J.; Xiong, H.; and Zhang, W. (2020). "Informer: Beyond Efficient Transformer for Long Sequence Time-Series Forecasting". Association for the Advancement of Artificial Intelligence Conference 2021 (AAAI 2021).](https://arxiv.org/abs/2012.07436)

# %% [markdown]
# ![Figure 1. Neural Hierarchical Interpolation for Time Series (NHITS).](imgs_models/nhits.png)

# %% [markdown]
# ## Install libraries

# %%
# %%capture
# !pip install git+https://github.com/nixtla/neuralforecast.git@main

# %%
#| export
from os import cpu_count
from typing import Tuple, Optional

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F

from ray import tune
from ray.tune.search.basic_variant import BasicVariantGenerator

from neuralforecast.losses.pytorch import MAE
from neuralforecast.common._base_windows import BaseWindows
from neuralforecast.common._base_auto import BaseAuto

# %%
#| hide
import logging
import warnings

from fastcore.test import test_eq
from neuralforecast.utils import generate_series

# %%
#| hide
logging.getLogger("pytorch_lightning").setLevel(logging.ERROR)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## N-HiTS setup

# %% [markdown]
# ### N-HiTS block

# %%
#| export
class _IdentityBasis(nn.Module):
    def __init__(self, backcast_size: int, forecast_size: int,
                 interpolation_mode: str, out_features: int=1):
        super().__init__()
        assert (interpolation_mode in ['linear','nearest']) or ('cubic' in interpolation_mode)
        self.forecast_size = forecast_size
        self.backcast_size = backcast_size
        self.interpolation_mode = interpolation_mode
        self.out_features = out_features

    def forward(self, theta: torch.Tensor) -> Tuple[torch.Tensor, torch.Tensor]:

        backcast = theta[:, :self.backcast_size]
        knots = theta[:, self.backcast_size:]

        # Interpolation is performed on default dim=-1 := H
        knots = knots.reshape(len(knots), self.out_features, -1)
        if self.interpolation_mode in ['nearest', 'linear']:
            #knots = knots[:,None,:]
            forecast = F.interpolate(knots, size=self.forecast_size, mode=self.interpolation_mode)
            #forecast = forecast[:,0,:]
        elif 'cubic' in self.interpolation_mode:
            if self.out_features>1:
                raise Exception('Cubic interpolation not available with multiple outputs.')
            batch_size = len(backcast)
            knots = knots[:,None,:,:]
            forecast = torch.zeros((len(knots), self.forecast_size), device=knots.device)
            n_batches = int(np.ceil(len(knots)/batch_size))
            for i in range(n_batches):
                forecast_i = F.interpolate(knots[i*batch_size:(i+1)*batch_size],
                                           size=self.forecast_size, mode='bicubic')
                forecast[i*batch_size:(i+1)*batch_size] += forecast_i[:,0,0,:] # [B,None,H,H] -> [B,H]
            forecast = forecast[:,None,:] # [B,H] -> [B,None,H]

        # [B,Q,H] -> [B,H,Q]
        forecast = forecast.permute(0, 2, 1)
        return backcast, forecast

# %%
#| exporti
ACTIVATIONS = ['ReLU',
               'Softplus',
               'Tanh',
               'SELU',
               'LeakyReLU',
               'PReLU',
               'Sigmoid']

POOLING = ['MaxPool1d',
           'AvgPool1d']

class NHITSBlock(nn.Module):
    """
    NHITS block which takes a basis function as an argument.
    """
    def __init__(self,
                 input_size: int,
                 h: int,
                 n_theta: int,
                 mlp_units: list,
                 basis: nn.Module,
                 futr_input_size: int,
                 hist_input_size: int,
                 stat_input_size: int,
                 n_pool_kernel_size: int,
                 pooling_mode: str,
                 dropout_prob: float,
                 activation: str):
        super().__init__()

        pooled_hist_size = int(np.ceil(input_size/n_pool_kernel_size))
        pooled_futr_size = int(np.ceil((input_size+h)/n_pool_kernel_size))

        input_size = pooled_hist_size + \
                     hist_input_size * pooled_hist_size + \
                     futr_input_size * pooled_futr_size + stat_input_size

        self.dropout_prob = dropout_prob
        self.futr_input_size = futr_input_size
        self.hist_input_size = hist_input_size
        self.stat_input_size = stat_input_size

        assert activation in ACTIVATIONS, f'{activation} is not in {ACTIVATIONS}'
        assert pooling_mode in POOLING, f'{pooling_mode} is not in {POOLING}'

        activ = getattr(nn, activation)()

        self.pooling_layer = getattr(nn, pooling_mode)(kernel_size=n_pool_kernel_size,
                                                       stride=n_pool_kernel_size, ceil_mode=True)

        # Block MLPs
        hidden_layers = [nn.Linear(in_features=input_size,
                                   out_features=mlp_units[0][0])]
        for layer in mlp_units:
            hidden_layers.append(nn.Linear(in_features=layer[0],
                                           out_features=layer[1]))
            hidden_layers.append(activ)

            if self.dropout_prob>0:
                #raise NotImplementedError('dropout')
                hidden_layers.append(nn.Dropout(p=self.dropout_prob))

        output_layer = [nn.Linear(in_features=mlp_units[-1][1], out_features=n_theta)]
        layers = hidden_layers + output_layer
        self.layers = nn.Sequential(*layers)
        self.basis = basis

    def forward(self, insample_y: torch.Tensor, futr_exog: torch.Tensor,
                hist_exog: torch.Tensor, stat_exog: torch.Tensor) -> Tuple[torch.Tensor, torch.Tensor]:

        # Pooling
        # Pool1d needs 3D input, (B,C,L), adding C dimension
        insample_y = insample_y.unsqueeze(1)
        insample_y = self.pooling_layer(insample_y)
        insample_y = insample_y.squeeze(1)

        # Flatten MLP inputs [B, L+H, C] -> [B, (L+H)*C]
        # Contatenate [ Y_t, | X_{t-L},..., X_{t} | F_{t-L},..., F_{t+H} | S ]
        batch_size = len(insample_y)
        if self.hist_input_size > 0:
            hist_exog = hist_exog.permute(0,2,1) # [B, L, C] -> [B, C, L]
            hist_exog = self.pooling_layer(hist_exog)
            hist_exog = hist_exog.permute(0,2,1) # [B, C, L] -> [B, L, C]
            insample_y = torch.cat(( insample_y, hist_exog.reshape(batch_size,-1) ), dim=1)

        if self.futr_input_size > 0:
            futr_exog = futr_exog.permute(0,2,1) # [B, L, C] -> [B, C, L]
            futr_exog = self.pooling_layer(futr_exog)
            futr_exog = futr_exog.permute(0,2,1) # [B, C, L] -> [B, L, C]
            insample_y = torch.cat(( insample_y, futr_exog.reshape(batch_size,-1) ), dim=1)

        if self.stat_input_size > 0:
            insample_y = torch.cat(( insample_y, stat_exog.reshape(batch_size,-1) ), dim=1)

        # Compute local projection weights and projection
        theta = self.layers(insample_y)
        backcast, forecast = self.basis(theta)
        return backcast, forecast

# %% [markdown]
# ### N-HiTS model

# %%
#| export
class NHITS(BaseWindows):
    """ NHITS

    The Neural Hierarchical Interpolation for Time Series (NHITS), is an MLP-based deep
    neural architecture with backward and forward residual links. NHITS tackles volatility and
    memory complexity challenges, by locally specializing its sequential predictions into
    the signals frequencies with hierarchical interpolation and pooling.

    **Parameters:**<br>
    `h`: int, Forecast horizon. <br>
    `input_size`: int, autorregresive inputs size, y=[1,2,3,4] input_size=2 -> y_[t-2:t]=[1,2].<br>
    `stat_exog_list`: str list, static exogenous columns.<br>
    `hist_exog_list`: str list, historic exogenous columns.<br>
    `futr_exog_list`: str list, future exogenous columns.<br>
    `exclude_insample_y`: bool=False, the model skips the autoregressive features y[t-input_size:t] if True.<br>
    `activation`: str, activation from ['ReLU', 'Softplus', 'Tanh', 'SELU', 'LeakyReLU', 'PReLU', 'Sigmoid'].<br>
    `stack_types`: List[str], stacks list in the form N * ['identity'], to be deprecated in favor of `n_stacks`. Note that len(stack_types)=len(n_freq_downsample)=len(n_pool_kernel_size).<br>
    `n_blocks`: List[int], Number of blocks for each stack. Note that len(n_blocks) = len(stack_types).<br>
    `mlp_units`: List[List[int]], Structure of hidden layers for each stack type. Each internal list should contain the number of units of each hidden layer. Note that len(n_hidden) = len(stack_types).<br>
    `n_freq_downsample`: List[int], list with the stack's coefficients (inverse expressivity ratios). Note that len(stack_types)=len(n_freq_downsample)=len(n_pool_kernel_size).<br>
    `interpolation_mode`: str='linear', interpolation basis from ['linear', 'nearest', 'cubic'].<br>
    `n_pool_kernel_size`: List[int], list with the size of the windows to take a max/avg over. Note that len(stack_types)=len(n_freq_downsample)=len(n_pool_kernel_size).<br>
    `pooling_mode`: str, input pooling module from ['MaxPool1d', 'AvgPool1d'].<br>
    `dropout_prob_theta`: float, Float between (0, 1). Dropout for NHITS basis.<br>
    `loss`: PyTorch module, instantiated train loss class from [losses collection](https://nixtla.github.io/neuralforecast/losses.pytorch.html).<br>
    `valid_loss`: PyTorch module=`loss`, instantiated valid loss class from [losses collection](https://nixtla.github.io/neuralforecast/losses.pytorch.html).<br>
    `max_steps`: int=1000, maximum number of training steps.<br>
    `learning_rate`: float=1e-3, Learning rate between (0, 1).<br>
    `num_lr_decays`: int=-1, Number of learning rate decays, evenly distributed across max_steps.<br>
    `early_stop_patience_steps`: int=-1, Number of validation iterations before early stopping.<br>
    `val_check_steps`: int=100, Number of training steps between every validation loss check.<br>
    `batch_size`: int=32, number of different series in each batch.<br>
    `valid_batch_size`: int=None, number of different series in each validation and test batch, if None uses batch_size.<br>
    `windows_batch_size`: int=1024, number of windows to sample in each training batch, default uses all.<br>
    `inference_windows_batch_size`: int=-1, number of windows to sample in each inference batch, -1 uses all.<br>
    `start_padding_enabled`: bool=False, if True, the model will pad the time series with zeros at the beginning, by input size.<br>
    `step_size`: int=1, step size between each window of temporal data.<br>
    `scaler_type`: str='identity', type of scaler for temporal inputs normalization see [temporal scalers](https://nixtla.github.io/neuralforecast/common.scalers.html).<br>
    `random_seed`: int, random_seed for pytorch initializer and numpy generators.<br>
    `num_workers_loader`: int=os.cpu_count(), workers to be used by `TimeSeriesDataLoader`.<br>
    `drop_last_loader`: bool=False, if True `TimeSeriesDataLoader` drops last non-full batch.<br>
    `alias`: str, optional,  Custom name of the model.<br>
    `optimizer`: Subclass of 'torch.optim.Optimizer', optional, user specified optimizer instead of the default choice (Adam).<br>
    `optimizer_kwargs`: dict, optional, list of parameters used by the user specified `optimizer`.<br>
    `lr_scheduler`: Subclass of 'torch.optim.lr_scheduler.LRScheduler', optional, user specified lr_scheduler instead of the default choice (StepLR).<br>
    `lr_scheduler_kwargs`: dict, optional, list of parameters used by the user specified `lr_scheduler`.<br>
    `**trainer_kwargs`: int,  keyword trainer arguments inherited from [PyTorch Lighning's trainer](https://pytorch-lightning.readthedocs.io/en/stable/api/pytorch_lightning.trainer.trainer.Trainer.html?highlight=trainer).<br>

    **References:**<br>
    -[Cristian Challu, Kin G. Olivares, Boris N. Oreshkin, Federico Garza,
    Max Mergenthaler-Canseco, Artur Dubrawski (2023). "NHITS: Neural Hierarchical Interpolation for Time Series Forecasting".
    Accepted at the Thirty-Seventh AAAI Conference on Artificial Intelligence.](https://arxiv.org/abs/2201.12886)
    """
    # Class attributes
    SAMPLING_TYPE = 'windows'
    EXOGENOUS_FUTR = True
    EXOGENOUS_HIST = True
    EXOGENOUS_STAT = True

    def __init__(self,
                 h,
                 input_size,
                 futr_exog_list = None,
                 hist_exog_list = None,
                 stat_exog_list = None,
                 exclude_insample_y = False,
                 stack_types: list = ['identity', 'identity', 'identity'],
                 n_blocks: list = [1, 1, 1],
                 mlp_units: list = 3 * [[512, 512]],
                 n_pool_kernel_size: list = [2, 2, 1],
                 n_freq_downsample: list = [4, 2, 1],
                 pooling_mode: str = 'MaxPool1d',
                 interpolation_mode: str = 'linear',
                 dropout_prob_theta = 0.,
                 activation = 'ReLU',
                 loss = MAE(),
                 valid_loss = None,
                 max_steps: int = 1000,
                 learning_rate: float = 1e-3,
                 num_lr_decays: int = 3,
                 early_stop_patience_steps: int =-1,
                 val_check_steps: int = 100,
                 batch_size: int = 32,
                 valid_batch_size: Optional[int] = None,
                 windows_batch_size: int = 1024,
                 inference_windows_batch_size: int = -1,
                 start_padding_enabled = False,
                 step_size: int = 1,
                 scaler_type: str = 'identity',
                 random_seed: int = 1,
                 num_workers_loader = 0,
                 drop_last_loader = False,
                 optimizer = None,
                 optimizer_kwargs = None,
                 lr_scheduler = None,
                 lr_scheduler_kwargs = None,
                 **trainer_kwargs):

        # Inherit BaseWindows class
        super(NHITS, self).__init__(h=h,
                                    input_size=input_size,
                                    futr_exog_list=futr_exog_list,
                                    hist_exog_list=hist_exog_list,
                                    stat_exog_list=stat_exog_list,
                                    exclude_insample_y = exclude_insample_y,
                                    loss=loss,
                                    valid_loss=valid_loss,
                                    max_steps=max_steps,
                                    learning_rate=learning_rate,
                                    num_lr_decays=num_lr_decays,
                                    early_stop_patience_steps=early_stop_patience_steps,
                                    val_check_steps=val_check_steps,
                                    batch_size=batch_size,
                                    windows_batch_size=windows_batch_size,
                                    valid_batch_size=valid_batch_size,
                                    inference_windows_batch_size=inference_windows_batch_size,
                                    start_padding_enabled=start_padding_enabled,
                                    step_size=step_size,
                                    scaler_type=scaler_type,
                                    num_workers_loader=num_workers_loader,
                                    drop_last_loader=drop_last_loader,
                                    random_seed=random_seed,
                                    optimizer=optimizer,
                                    optimizer_kwargs=optimizer_kwargs,
                                    lr_scheduler=lr_scheduler,
                                    lr_scheduler_kwargs=lr_scheduler_kwargs,
                                    **trainer_kwargs)

        # Architecture
        blocks = self.create_stack(h=h,
                                   input_size=input_size,
                                   stack_types=stack_types,
                                   futr_input_size=self.futr_exog_size,
                                   hist_input_size=self.hist_exog_size,
                                   stat_input_size=self.stat_exog_size,
                                   n_blocks=n_blocks,
                                   mlp_units=mlp_units,
                                   n_pool_kernel_size=n_pool_kernel_size,
                                   n_freq_downsample=n_freq_downsample,
                                   pooling_mode=pooling_mode,
                                   interpolation_mode=interpolation_mode,
                                   dropout_prob_theta=dropout_prob_theta,
                                   activation=activation)
        self.blocks = torch.nn.ModuleList(blocks)

    def create_stack(self,
                     h,
                     input_size,
                     stack_types,
                     n_blocks,
                     mlp_units,
                     n_pool_kernel_size,
                     n_freq_downsample,
                     pooling_mode,
                     interpolation_mode,
                     dropout_prob_theta,
                     activation,
                     futr_input_size, hist_input_size, stat_input_size):

        block_list = []
        for i in range(len(stack_types)):
            for block_id in range(n_blocks[i]):

                assert stack_types[i] == 'identity', f'Block type {stack_types[i]} not found!'

                n_theta = (input_size + self.loss.outputsize_multiplier*max(h//n_freq_downsample[i], 1) )
                basis = _IdentityBasis(backcast_size=input_size, forecast_size=h,
                                       out_features=self.loss.outputsize_multiplier,
                                       interpolation_mode=interpolation_mode)

                nbeats_block = NHITSBlock(h=h,
                                          input_size=input_size,
                                          futr_input_size=futr_input_size,
                                          hist_input_size=hist_input_size,
                                          stat_input_size=stat_input_size,
                                          n_theta=n_theta,
                                          mlp_units=mlp_units,
                                          n_pool_kernel_size=n_pool_kernel_size[i],
                                          pooling_mode=pooling_mode,
                                          basis=basis,
                                          dropout_prob=dropout_prob_theta,
                                          activation=activation)

                # Select type of evaluation and apply it to all layers of block
                block_list.append(nbeats_block)

        return block_list

    def forward(self, windows_batch):

        # Parse windows_batch
        insample_y    = windows_batch['insample_y']
        insample_mask = windows_batch['insample_mask']
        futr_exog     = windows_batch['futr_exog']
        hist_exog     = windows_batch['hist_exog']
        stat_exog     = windows_batch['stat_exog']

        # insample
        residuals = insample_y.flip(dims=(-1,)) #backcast init
        insample_mask = insample_mask.flip(dims=(-1,))

        forecast = insample_y[:, -1:, None] # Level with Naive1
        block_forecasts = [ forecast.repeat(1, self.h, 1) ]
        for i, block in enumerate(self.blocks):
            backcast, block_forecast = block(insample_y=residuals, futr_exog=futr_exog,
                                             hist_exog=hist_exog, stat_exog=stat_exog)
            residuals = (residuals - backcast) * insample_mask
            forecast = forecast + block_forecast

            if self.decompose_forecast:
                block_forecasts.append(block_forecast)

        # Adapting output's domain
        forecast = self.loss.domain_map(forecast)

        if self.decompose_forecast:
            # (n_batch, n_blocks, h, output_size)
            block_forecasts = torch.stack(block_forecasts)
            block_forecasts = block_forecasts.permute(1,0,2,3)
            block_forecasts = block_forecasts.squeeze(-1) # univariate output
            return block_forecasts
        else:
            return forecast

# %% [markdown]
# ### Auto N-HiTS

# %%
#| export
class AutoNHITS(BaseAuto):

    default_config = {
       "input_size_multiplier": [1, 2, 3, 4, 5],
       "h": None,
       "n_pool_kernel_size": tune.choice([[2, 2, 1], 3*[1], 3*[2], 3*[4],
                                         [8, 4, 1], [16, 8, 1]]),
       "n_freq_downsample": tune.choice([[168, 24, 1], [24, 12, 1],
                                         [180, 60, 1], [60, 8, 1],
                                         [40, 20, 1], [1, 1, 1]]),
       "learning_rate": tune.loguniform(1e-4, 1e-1),
       "scaler_type": tune.choice([None, 'robust', 'standard']),
       "max_steps": tune.quniform(lower=500, upper=1500, q=100),
       "batch_size": tune.choice([32, 64, 128, 256]),
       "windows_batch_size": tune.choice([128, 256, 512, 1024]),
       "loss": None,
       "random_seed": tune.randint(lower=1, upper=20),
    }

    def __init__(self,
                 h,
                 loss=MAE(),
                 valid_loss=None,
                 config=None,
                 search_alg=BasicVariantGenerator(random_state=1),
                 num_samples=10,
                 refit_with_val=False,
                 cpus=cpu_count(),
                 gpus=torch.cuda.device_count(),
                 verbose=False,
                 alias=None,
                 backend='ray',
                 callbacks=None,
                ):

        # Define search space, input/output sizes
        if config is None:
            config = self.get_default_config(h=h, backend=backend)

        super(AutoNHITS, self).__init__(
              cls_model=NHITS,
              h=h,
              loss=loss,
              valid_loss=valid_loss,
              config=config,
              search_alg=search_alg,
              num_samples=num_samples,
              refit_with_val=refit_with_val,
              cpus=cpus,
              gpus=gpus,
              verbose=verbose,
              alias=alias,
              backend=backend,
              callbacks=callbacks,
        )

    @classmethod
    def get_default_config(cls, h, backend, n_series=None):
        config = cls.default_config.copy()
        config['input_size'] = tune.choice([h*x \
                        for x in config['input_size_multiplier']])
        config['step_size'] = tune.choice([1, h])
        del config['input_size_multiplier']
        if backend == 'optuna':
            config = cls._ray_config_to_optuna(config)

        return config

# %% [markdown]
# ### Show doc

# %%
# %%capture
# !pip install nbdev

# %%
# from nbdev.showdoc import show_doc

# %%
# show_doc(NHITS, title_level=3)

# %%
# show_doc(NHITS.fit, name='NHITS.fit', title_level=3)

# %%
# show_doc(NHITS.predict, name='NHITS.predict', title_level=3)

# %%
# show_doc(AutoNHITS, name='AutoNHITS', title_level=3)

# %% [markdown]
# ## Data processing

# %%
#| hide
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from neuralforecast.tsdataset import TimeSeriesDataset

# %% [markdown]
# ### Handle missing data and tranform with Min-Max scaler

# %%
scaler = MinMaxScaler()

def process_data(stock_data, scaler=scaler):
    stock_data['Date'] = pd.to_datetime(stock_data['Date'])

    stock_data['Close'] = scaler.fit_transform(stock_data[['Close']])

    df = pd.DataFrame({
        'ds': stock_data['Date'],
        'unique_id': 1,
        'y': stock_data['Close']
    })


    df.sort_values(by=['ds'], inplace=True, ascending=True)

    df.dropna(inplace=True)
    df.drop_duplicates(inplace=True)

    # handle missing data
    start_date = df['ds'].min()
    end_date = df['ds'].max()
    date_range = pd.date_range(start=start_date, end=end_date, freq='D')

    filtered_dates = [date for date in date_range if date.weekday() < 5]  # 0-4: Monday-Friday
    full_date = pd.DataFrame({'ds': filtered_dates})

    df = pd.merge(full_date,df,on='ds',how='left')
    df.ffill(inplace=True)

    df = df[['unique_id', 'ds', 'y']]

    return df

# %%
# Read data
stock_data = pd.read_csv(f'{DATASET_NAME}.csv')
stock_data['Date'] = pd.to_datetime(stock_data['Date'])

df = process_data(stock_data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1371 entries, 0 to 1370
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   unique_id  1371 non-null   float64
#  1   ds         1371 non-null   datetime64[ns, UTC+07:00]
#  2   y          1371 non-null   float64
# dtypes: datetime64[ns, UTC+07:00](1), float64(2)
# memory usage: 32.3 KB

# %%
df.head(10)
# Out:
#    unique_id                        ds         y
# 0        1.0 2019-03-01 00:00:00+07:00  0.048385
# 1        1.0 2019-03-04 00:00:00+07:00  0.064513
# 2        1.0 2019-03-05 00:00:00+07:00  0.086018
# 3        1.0 2019-03-06 00:00:00+07:00  0.089244
# 4        1.0 2019-03-07 00:00:00+07:00  0.092469
# 5        1.0 2019-03-08 00:00:00+07:00  0.073115
# 6        1.0 2019-03-11 00:00:00+07:00  0.065589
# 7        1.0 2019-03-12 00:00:00+07:00  0.105372
# 8        1.0 2019-03-13 00:00:00+07:00  0.107522
# 9        1.0 2019-03-14 00:00:00+07:00  0.120425

# %% [markdown]
# ### Split train-test

# %%
n_time = len(df['ds'].unique())
train_size = int((1-TEST_RATIO) * n_time)
test_size = int(n_time-train_size)

Y_train_df = df[:-test_size]
Y_test_df = df[-test_size:]

# %%
print(f'Train shape: {Y_train_df.shape}')
print(f'Test shape: {Y_test_df.shape}')
# Out:
# Train shape: (1233, 3)
# Test shape: (138, 3)

# %% [markdown]
# ## Train and Predict with N-HiTS

# %% [markdown]
# ### Train model and Tuning the hyperparameters

# %%
HORIZON = 10

# %%
nhits_config = {
       "learning_rate": tune.choice([1e-3]),                                     # Initial Learning rate
       "max_steps": tune.choice([100]),                                          # Number of SGD steps
       "input_size": tune.choice([5*HORIZON]),                                   # input_size = multiplier * horizon
       "batch_size": tune.choice([7]),                                           # Number of series in windows
       "windows_batch_size": tune.choice([256]),                                 # Number of windows in batch
       "n_pool_kernel_size": tune.choice([[2, 2, 2], [16, 8, 1]]),               # MaxPool's Kernelsize
       "n_freq_downsample": tune.choice([[168, 24, 1], [24, 12, 1], [1, 1, 1]]), # Interpolation expressivity ratios
       "activation": tune.choice(['ReLU']),                                      # Type of non-linear activation
       "n_blocks":  tune.choice([[1, 1, 1]]),                                    # Blocks per each 3 stacks
       "mlp_units":  tune.choice([[[512, 512], [512, 512], [512, 512]]]),        # 2 512-Layers per block for each stack
       "interpolation_mode": tune.choice(['linear']),                            # Type of multi-step interpolation
       "val_check_steps": tune.choice([100]),                                    # Compute validation every 100 epochs
       "random_seed": tune.randint(1, 10),
    }

# %%
model = AutoNHITS(
    h=HORIZON,
    loss=MAE(),
    config=nhits_config,
    num_samples=5,
)

# %%
traindata, *_ = TimeSeriesDataset.from_df(df = Y_train_df)

# %%
# model.fit(dataset=traindata, val_size=HORIZON)
model.fit(dataset=traindata)
# Out:
# 2024-06-18 05:42:26,284	INFO worker.py:1753 -- Started a local Ray instance.
# 2024-06-18 05:42:31,262	INFO tune.py:253 -- Initializing Ray automatically. For cluster usage or custom Ray initialization, call `ray.init(...)` before `Tuner(...)`.
# +--------------------------------------------------------------------+
# | Configuration for experiment     _train_tune_2024-06-18_05-42-21   |
# +--------------------------------------------------------------------+
# | Search algorithm                 BasicVariantGenerator             |
# | Scheduler                        FIFOScheduler                     |
# | Number of trials                 5                                 |
# +--------------------------------------------------------------------+
#
# View detailed results here: /root/ray_results/_train_tune_2024-06-18_05-42-21
# To visualize your results with TensorBoard, run: `tensorboard --logdir /tmp/ray/session_2024-06-18_05-42-21_160125_5407/artifacts/2024-06-18_05-42-31/_train_tune_2024-06-18_05-42-21/driver_artifacts`
# (_train_tune pid=6062) /usr/local/lib/python3.10/dist-packages/ray/tune/integration/pytorch_lightning.py:198: `ray.tune.integration.pytorch_lightning.TuneReportCallback` is deprecated. Use `ray.tune.integration.pytorch_lightning.TuneReportCheckpointCallback` instead.
# (_train_tune pid=6062) Seed set to 4
# (_train_tune pid=6062) GPU available: False, used: False
# (_train_tune pid=6062) TPU available: False, using: 0 TPU cores
# (_train_tune pid=6062) HPU available: False, using: 0 HPUs
# (_train_tune pid=6062) Missing logger folder: /tmp/ray/session_2024-06-18_05-42-21_160125_5407/artifacts/2024-06-18_05-42-31/_train_tune_2024-06-18_05-42-21/working_dirs/_train_tune_8698d_00000_0_activation=ReLU,batch_size=7,input_size=50,interpolation_mode=linear,learning_rate=0.0010,max_steps=100,_2024-06-18_05-42-32/lightning_logs
# (_train_tune pid=6062) 2024-06-18 05:42:57.614269: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (_train_tune pid=6062) 2024-06-18 05:42:57.614356: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (_train_tune pid=6062) 2024-06-18 05:42:57.618597: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (_train_tune pid=6062) 2024-06-18 05:42:57.641201: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# (_train_tune pid=6062) To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (_train_tune pid=6062) 2024-06-18 05:42:59.625732: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (_train_tune pid=6062)
# (_train_tune pid=6062)   | Name         | Type          | Params | Mode
# (_train_tune pid=6062) -------------------------------------------------------
# (_train_tune pid=6062) 0 | loss         | MAE           | 0      | train
# (_train_tune pid=6062) 1 | padder_train | ConstantPad1d | 0      | train
# (_train_tune pid=6062) 2 | scaler       | TemporalNorm  | 0      | train
# (_train_tune pid=6062) 3 | blocks       | ModuleList    | 2.5 M  | train
# (_train_tune pid=6062) -------------------------------------------------------
# (_train_tune pid=6062) 2.5 M     Trainable params
# (_train_tune pid=6062) 0         Non-trainable params
# (_train_tune pid=6062) 2.5 M     Total params
# (_train_tune pid=6062) 9.948     Total estimated model params size (MB)
# Epoch 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 1:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0505, train_loss_epoch=0.0505]
# Epoch 2:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.367, train_loss_epoch=0.367]
# Epoch 3:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.131, train_loss_epoch=0.131]
# Epoch 4:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0468, train_loss_epoch=0.0468]
# Epoch 5:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.052, train_loss_epoch=0.052]
# Epoch 6:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0338, train_loss_epoch=0.0338]
# Epoch 7:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0428, train_loss_epoch=0.0428]
# Epoch 8:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.036, train_loss_epoch=0.036]
# Epoch 9:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0389, train_loss_epoch=0.0389]
# Epoch 10:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0408, train_loss_epoch=0.0408]
# Epoch 11:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0342, train_loss_epoch=0.0342]
# Epoch 12:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0347, train_loss_epoch=0.0347]
# Epoch 13:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.037, train_loss_epoch=0.037]
# Epoch 14:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0346, train_loss_epoch=0.0346]
# Epoch 15:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0331, train_loss_epoch=0.0331]
# Epoch 16:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0333, train_loss_epoch=0.0333]
# Epoch 17:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.034, train_loss_epoch=0.034]
# Epoch 18:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0332, train_loss_epoch=0.0332]
# Epoch 19:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.033, train_loss_epoch=0.033]
# Epoch 20:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0347, train_loss_epoch=0.0347]
# Epoch 21:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0324, train_loss_epoch=0.0324]
# Epoch 22:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0336, train_loss_epoch=0.0336]
# Epoch 23:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0297, train_loss_epoch=0.0297]
# Epoch 24:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0331, train_loss_epoch=0.0331]
# Epoch 25:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0339, train_loss_epoch=0.0339]
# Epoch 26:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0312, train_loss_epoch=0.0312]
# Epoch 27:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0337, train_loss_epoch=0.0337]
# Epoch 28:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0349, train_loss_epoch=0.0349]
# Epoch 29:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0343, train_loss_epoch=0.0343]
# Epoch 30:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0361, train_loss_epoch=0.0361]
# Epoch 31:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0306, train_loss_epoch=0.0306]
# Epoch 31: 100%|██████████| 1/1 [00:00<00:00,  8.63it/s, v_num=0, train_loss_step=0.0306, train_loss_epoch=0.0306]
# Epoch 31: 100%|██████████| 1/1 [00:00<00:00,  8.52it/s, v_num=0, train_loss_step=0.0349, train_loss_epoch=0.0349]
# Epoch 32:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0349, train_loss_epoch=0.0349]
# Epoch 33:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0324, train_loss_epoch=0.0324]
# Epoch 34:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0336, train_loss_epoch=0.0336]
# Epoch 35:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0318, train_loss_epoch=0.0318]
# Epoch 36:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0347, train_loss_epoch=0.0347]
# Epoch 37:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0313, train_loss_epoch=0.0313]
# Epoch 38:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0321, train_loss_epoch=0.0321]
# Epoch 39:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0322, train_loss_epoch=0.0322]
# Epoch 40:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0345, train_loss_epoch=0.0345]
# Epoch 41:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0316, train_loss_epoch=0.0316]
# Epoch 42:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0329, train_loss_epoch=0.0329]
# Epoch 43:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0353, train_loss_epoch=0.0353]
# Epoch 44:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0341, train_loss_epoch=0.0341]
# Epoch 45:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0318, train_loss_epoch=0.0318]
# Epoch 46:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.032, train_loss_epoch=0.032]
# Epoch 47:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0339, train_loss_epoch=0.0339]
# Epoch 48:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0337, train_loss_epoch=0.0337]
# Epoch 49:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0316, train_loss_epoch=0.0316]
# Epoch 50:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0349, train_loss_epoch=0.0349]
# Epoch 51:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0336, train_loss_epoch=0.0336]
# Epoch 52:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0344, train_loss_epoch=0.0344]
# Epoch 53:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0329, train_loss_epoch=0.0329]
# Epoch 54:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.033, train_loss_epoch=0.033]
# Epoch 55:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0328, train_loss_epoch=0.0328]
# Epoch 56:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0322, train_loss_epoch=0.0322]
# Epoch 57:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0313, train_loss_epoch=0.0313]
# Epoch 58:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0326, train_loss_epoch=0.0326]
# Epoch 59:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.033, train_loss_epoch=0.033]
# Epoch 60:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0326, train_loss_epoch=0.0326]
# Epoch 61:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0343, train_loss_epoch=0.0343]
# Epoch 62:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0338, train_loss_epoch=0.0338]
# Epoch 63:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.032, train_loss_epoch=0.032]
# Epoch 64:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0308, train_loss_epoch=0.0308]
# Epoch 65:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0343, train_loss_epoch=0.0343]
# Epoch 66:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0325, train_loss_epoch=0.0325]
# Epoch 67:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0318, train_loss_epoch=0.0318]
# Epoch 68:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.032, train_loss_epoch=0.032]
# Epoch 69:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.033, train_loss_epoch=0.033]
# Epoch 69: 100%|██████████| 1/1 [00:00<00:00,  7.84it/s, v_num=0, train_loss_step=0.0307, train_loss_epoch=0.033]
# Epoch 70:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0307, train_loss_epoch=0.0307]
# Epoch 71:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0299, train_loss_epoch=0.0299]
# Epoch 72:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0318, train_loss_epoch=0.0318]
# Epoch 73:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0339, train_loss_epoch=0.0339]
# Epoch 74:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0321, train_loss_epoch=0.0321]
# Epoch 75:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0319, train_loss_epoch=0.0319]
# Epoch 76:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0323, train_loss_epoch=0.0323]
# Epoch 77:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0318, train_loss_epoch=0.0318]
# Epoch 78:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.033, train_loss_epoch=0.033]
# Epoch 79:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0332, train_loss_epoch=0.0332]
# Epoch 80:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.033, train_loss_epoch=0.033]
# Epoch 81:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0319, train_loss_epoch=0.0319]
# Epoch 82:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0336, train_loss_epoch=0.0336]
# Epoch 83:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0331, train_loss_epoch=0.0331]
# Epoch 84:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0334, train_loss_epoch=0.0334]
# Epoch 85:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0317, train_loss_epoch=0.0317]
# Epoch 86:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0323, train_loss_epoch=0.0323]
# Epoch 87:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.034, train_loss_epoch=0.034]
# Epoch 88:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0337, train_loss_epoch=0.0337]
# Epoch 89:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0352, train_loss_epoch=0.0352]
# Epoch 90:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0322, train_loss_epoch=0.0322]
# Epoch 91:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0321, train_loss_epoch=0.0321]
# Epoch 92:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0328, train_loss_epoch=0.0328]
# Epoch 93:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0309, train_loss_epoch=0.0309]
# Epoch 93: 100%|██████████| 1/1 [00:00<00:00,  8.43it/s, v_num=0, train_loss_step=0.0322, train_loss_epoch=0.0322]
# Epoch 94:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0322, train_loss_epoch=0.0322]
# Epoch 95:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0345, train_loss_epoch=0.0345]
# Epoch 96:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0307, train_loss_epoch=0.0307]
# Epoch 97:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0314, train_loss_epoch=0.0314]
# Epoch 98:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0317, train_loss_epoch=0.0317]
# Epoch 99:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.033, train_loss_epoch=0.033]
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00,  6.02it/s, v_num=0, train_loss_step=0.0311, train_loss_epoch=0.033]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 136.77it/s]
# (_train_tune pid=6062) `Trainer.fit` stopped: `max_steps=100` reached.
# (_train_tune pid=6062)
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00,  4.85it/s, v_num=0, train_loss_step=0.0311, train_loss_epoch=0.0311, valid_loss=0.0385]
# (_train_tune pid=6306) /usr/local/lib/python3.10/dist-packages/ray/tune/integration/pytorch_lightning.py:198: `ray.tune.integration.pytorch_lightning.TuneReportCallback` is deprecated. Use `ray.tune.integration.pytorch_lightning.TuneReportCheckpointCallback` instead.
# (_train_tune pid=6306) Seed set to 6
# (_train_tune pid=6306) GPU available: False, used: False
# (_train_tune pid=6306) TPU available: False, using: 0 TPU cores
# (_train_tune pid=6306) HPU available: False, using: 0 HPUs
# (_train_tune pid=6306) Missing logger folder: /tmp/ray/session_2024-06-18_05-42-21_160125_5407/artifacts/2024-06-18_05-42-31/_train_tune_2024-06-18_05-42-21/working_dirs/_train_tune_8698d_00001_1_activation=ReLU,batch_size=7,input_size=50,interpolation_mode=linear,learning_rate=0.0010,max_steps=100,_2024-06-18_05-42-32/lightning_logs
# (_train_tune pid=6306) 2024-06-18 05:43:26.104888: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (_train_tune pid=6306) 2024-06-18 05:43:26.104981: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (_train_tune pid=6306) 2024-06-18 05:43:26.106702: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (_train_tune pid=6306) 2024-06-18 05:43:26.116823: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# (_train_tune pid=6306) To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (_train_tune pid=6306) 2024-06-18 05:43:27.593427: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (_train_tune pid=6306)
# (_train_tune pid=6306)   | Name         | Type          | Params | Mode
# (_train_tune pid=6306) -------------------------------------------------------
# (_train_tune pid=6306) 0 | loss         | MAE           | 0      | train
# (_train_tune pid=6306) 1 | padder_train | ConstantPad1d | 0      | train
# (_train_tune pid=6306) 2 | scaler       | TemporalNorm  | 0      | train
# (_train_tune pid=6306) 3 | blocks       | ModuleList    | 2.5 M  | train
# (_train_tune pid=6306) -------------------------------------------------------
# (_train_tune pid=6306) 2.5 M     Trainable params
# (_train_tune pid=6306) 0         Non-trainable params
# (_train_tune pid=6306) 2.5 M     Total params
# (_train_tune pid=6306) 9.985     Total estimated model params size (MB)
# Sanity Checking DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 0: 100%|██████████| 1/1 [00:00<00:00,  5.24it/s, v_num=0, train_loss_step=0.0446]
# Epoch 1:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0446, train_loss_epoch=0.0446]
# Epoch 2:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.144, train_loss_epoch=0.144]
# Epoch 3:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0674, train_loss_epoch=0.0674]
# Epoch 4:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0448, train_loss_epoch=0.0448]
# Epoch 5:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0458, train_loss_epoch=0.0458]
# Epoch 6:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0433, train_loss_epoch=0.0433]
# Epoch 7:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0351, train_loss_epoch=0.0351]
# Epoch 8:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.034, train_loss_epoch=0.034]
# Epoch 9:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0343, train_loss_epoch=0.0343]
# Epoch 10:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0337, train_loss_epoch=0.0337]
# Epoch 11:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0319, train_loss_epoch=0.0319]
# Epoch 12:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0346, train_loss_epoch=0.0346]
# Epoch 13:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0332, train_loss_epoch=0.0332]
# Epoch 14:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0323, train_loss_epoch=0.0323]
# Epoch 15:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0315, train_loss_epoch=0.0315]
# Epoch 16:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0344, train_loss_epoch=0.0344]
# Epoch 17:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0345, train_loss_epoch=0.0345]
# Epoch 18:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0327, train_loss_epoch=0.0327]
# Epoch 19:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0361, train_loss_epoch=0.0361]
# Epoch 20:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0345, train_loss_epoch=0.0345]
# Epoch 21:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0354, train_loss_epoch=0.0354]
# Epoch 22:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0324, train_loss_epoch=0.0324]
# Epoch 23:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0368, train_loss_epoch=0.0368]
# Epoch 24:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0342, train_loss_epoch=0.0342]
# Epoch 25:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0352, train_loss_epoch=0.0352]
# Epoch 26:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0348, train_loss_epoch=0.0348]
# Epoch 27:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0343, train_loss_epoch=0.0343]
# Epoch 28:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0357, train_loss_epoch=0.0357]
# Epoch 29:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0332, train_loss_epoch=0.0332]
# Epoch 30:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.033, train_loss_epoch=0.033]
# Epoch 31:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0342, train_loss_epoch=0.0342]
# Epoch 32:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0334, train_loss_epoch=0.0334]
# Epoch 33:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0337, train_loss_epoch=0.0337]
# Epoch 34:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0315, train_loss_epoch=0.0315]
# Epoch 35:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.032, train_loss_epoch=0.032]
# Epoch 36:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0338, train_loss_epoch=0.0338]
# Epoch 37:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0353, train_loss_epoch=0.0353]
# Epoch 38:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0328, train_loss_epoch=0.0328]
# Epoch 39:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0297, train_loss_epoch=0.0297]
# Epoch 40:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.033, train_loss_epoch=0.033]
# Epoch 41:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0322, train_loss_epoch=0.0322]
# Epoch 42:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0346, train_loss_epoch=0.0346]
# Epoch 43:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0351, train_loss_epoch=0.0351]
# Epoch 44:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0312, train_loss_epoch=0.0312]
# Epoch 45:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0296, train_loss_epoch=0.0296]
# Epoch 46:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0327, train_loss_epoch=0.0327]
# Epoch 47:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0363, train_loss_epoch=0.0363]
# Epoch 48:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0333, train_loss_epoch=0.0333]
# Epoch 49:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0304, train_loss_epoch=0.0304]
# Epoch 50:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0329, train_loss_epoch=0.0329]
# Epoch 51:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0316, train_loss_epoch=0.0316]
# Epoch 52:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0328, train_loss_epoch=0.0328]
# Epoch 53:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0328, train_loss_epoch=0.0328]
# Epoch 54:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0327, train_loss_epoch=0.0327]
# Epoch 55:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0317, train_loss_epoch=0.0317]
# Epoch 56:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0311, train_loss_epoch=0.0311]
# Epoch 57:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0313, train_loss_epoch=0.0313]
# Epoch 58:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.031, train_loss_epoch=0.031]
# Epoch 59:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0331, train_loss_epoch=0.0331]
# Epoch 60:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0324, train_loss_epoch=0.0324]
# Epoch 61:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0324, train_loss_epoch=0.0324]
# Epoch 62:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0324, train_loss_epoch=0.0324]
# Epoch 63:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0316, train_loss_epoch=0.0316]
# Epoch 64:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.032, train_loss_epoch=0.032]
# Epoch 65:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.034, train_loss_epoch=0.034]
# Epoch 66:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0321, train_loss_epoch=0.0321]
# Epoch 67:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0355, train_loss_epoch=0.0355]
# Epoch 68:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0331, train_loss_epoch=0.0331]
# Epoch 69:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0328, train_loss_epoch=0.0328]
# Epoch 70:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.032, train_loss_epoch=0.032]
# Epoch 71:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0321, train_loss_epoch=0.0321]
# Epoch 72:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0309, train_loss_epoch=0.0309]
# Epoch 73:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0331, train_loss_epoch=0.0331]
# Epoch 74:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0309, train_loss_epoch=0.0309]
# Epoch 75:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0334, train_loss_epoch=0.0334]
# Epoch 76:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0339, train_loss_epoch=0.0339]
# Epoch 77:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0325, train_loss_epoch=0.0325]
# Epoch 78:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.034, train_loss_epoch=0.034]
# Epoch 79:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0335, train_loss_epoch=0.0335]
# Epoch 80:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0303, train_loss_epoch=0.0303]
# Epoch 81:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0332, train_loss_epoch=0.0332]
# Epoch 82:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0321, train_loss_epoch=0.0321]
# Epoch 83:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0319, train_loss_epoch=0.0319]
# Epoch 84:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0359, train_loss_epoch=0.0359]
# Epoch 85:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0334, train_loss_epoch=0.0334]
# Epoch 86:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0328, train_loss_epoch=0.0328]
# Epoch 87:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0325, train_loss_epoch=0.0325]
# Epoch 88:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0338, train_loss_epoch=0.0338]
# Epoch 89:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0323, train_loss_epoch=0.0323]
# Epoch 90:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0318, train_loss_epoch=0.0318]
# Epoch 91:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0302, train_loss_epoch=0.0302]
# Epoch 92:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0336, train_loss_epoch=0.0336]
# Epoch 93:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0325, train_loss_epoch=0.0325]
# Epoch 94:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0324, train_loss_epoch=0.0324]
# Epoch 95:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0343, train_loss_epoch=0.0343]
# Epoch 96:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0312, train_loss_epoch=0.0312]
# Epoch 97:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0323, train_loss_epoch=0.0323]
# Epoch 98:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0344, train_loss_epoch=0.0344]
# Epoch 99:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0321, train_loss_epoch=0.0321]
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00,  9.15it/s, v_num=0, train_loss_step=0.0323, train_loss_epoch=0.0321]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# (_train_tune pid=6306) `Trainer.fit` stopped: `max_steps=100` reached.
# (_train_tune pid=6306)
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 166.70it/s]
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00,  7.54it/s, v_num=0, train_loss_step=0.0323, train_loss_epoch=0.0323, valid_loss=0.0425]
# (_train_tune pid=6483) /usr/local/lib/python3.10/dist-packages/ray/tune/integration/pytorch_lightning.py:198: `ray.tune.integration.pytorch_lightning.TuneReportCallback` is deprecated. Use `ray.tune.integration.pytorch_lightning.TuneReportCheckpointCallback` instead.
# (_train_tune pid=6483) Seed set to 3
# (_train_tune pid=6483) GPU available: False, used: False
# (_train_tune pid=6483) TPU available: False, using: 0 TPU cores
# (_train_tune pid=6483) HPU available: False, using: 0 HPUs
# (_train_tune pid=6483) Missing logger folder: /tmp/ray/session_2024-06-18_05-42-21_160125_5407/artifacts/2024-06-18_05-42-31/_train_tune_2024-06-18_05-42-21/working_dirs/_train_tune_8698d_00002_2_activation=ReLU,batch_size=7,input_size=50,interpolation_mode=linear,learning_rate=0.0010,max_steps=100,_2024-06-18_05-42-32/lightning_logs
# (_train_tune pid=6483) 2024-06-18 05:43:53.558631: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (_train_tune pid=6483) 2024-06-18 05:43:53.558694: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (_train_tune pid=6483) 2024-06-18 05:43:53.560624: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (_train_tune pid=6483) 2024-06-18 05:43:53.572067: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# (_train_tune pid=6483) To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (_train_tune pid=6483) 2024-06-18 05:43:55.021978: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (_train_tune pid=6483)
# (_train_tune pid=6483)   | Name         | Type          | Params | Mode
# (_train_tune pid=6483) -------------------------------------------------------
# (_train_tune pid=6483) 0 | loss         | MAE           | 0      | train
# (_train_tune pid=6483) 1 | padder_train | ConstantPad1d | 0      | train
# (_train_tune pid=6483) 2 | scaler       | TemporalNorm  | 0      | train
# (_train_tune pid=6483) 3 | blocks       | ModuleList    | 2.5 M  | train
# (_train_tune pid=6483) -------------------------------------------------------
# (_train_tune pid=6483) 2.5 M     Trainable params
# (_train_tune pid=6483) 0         Non-trainable params
# (_train_tune pid=6483) 2.5 M     Total params
# (_train_tune pid=6483) 9.948     Total estimated model params size (MB)
# Epoch 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 1:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0438, train_loss_epoch=0.0438]
# Epoch 2:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.187, train_loss_epoch=0.187]
# Epoch 3:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.238, train_loss_epoch=0.238]
# Epoch 4:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.120, train_loss_epoch=0.120]
# Epoch 5:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0426, train_loss_epoch=0.0426]
# Epoch 6:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0695, train_loss_epoch=0.0695]
# Epoch 7:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0434, train_loss_epoch=0.0434]
# Epoch 8:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0414, train_loss_epoch=0.0414]
# Epoch 9:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0441, train_loss_epoch=0.0441]
# Epoch 10:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0374, train_loss_epoch=0.0374]
# Epoch 11:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0368, train_loss_epoch=0.0368]
# Epoch 12:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.037, train_loss_epoch=0.037]
# Epoch 13:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0358, train_loss_epoch=0.0358]
# Epoch 14:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0349, train_loss_epoch=0.0349]
# Epoch 15:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0332, train_loss_epoch=0.0332]
# Epoch 16:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0358, train_loss_epoch=0.0358]
# Epoch 17:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.037, train_loss_epoch=0.037]
# Epoch 18:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0347, train_loss_epoch=0.0347]
# Epoch 19:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0323, train_loss_epoch=0.0323]
# Epoch 20:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0326, train_loss_epoch=0.0326]
# Epoch 21:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0331, train_loss_epoch=0.0331]
# Epoch 22:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0338, train_loss_epoch=0.0338]
# Epoch 23:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0351, train_loss_epoch=0.0351]
# Epoch 24:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.033, train_loss_epoch=0.033]
# Epoch 25:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0373, train_loss_epoch=0.0373]
# Epoch 26:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0317, train_loss_epoch=0.0317]
# Epoch 27:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0323, train_loss_epoch=0.0323]
# Epoch 28:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0321, train_loss_epoch=0.0321]
# Epoch 29:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0346, train_loss_epoch=0.0346]
# Epoch 30:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0346, train_loss_epoch=0.0346]
# Epoch 31:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0325, train_loss_epoch=0.0325]
# Epoch 32:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0329, train_loss_epoch=0.0329]
# Epoch 33:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0328, train_loss_epoch=0.0328]
# Epoch 34:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0332, train_loss_epoch=0.0332]
# Epoch 35:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.032, train_loss_epoch=0.032]
# Epoch 36:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0339, train_loss_epoch=0.0339]
# Epoch 37:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0319, train_loss_epoch=0.0319]
# Epoch 38:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0361, train_loss_epoch=0.0361]
# Epoch 39:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0344, train_loss_epoch=0.0344]
# Epoch 40:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0315, train_loss_epoch=0.0315]
# Epoch 41:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0334, train_loss_epoch=0.0334]
# Epoch 42:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.034, train_loss_epoch=0.034]
# Epoch 43:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0307, train_loss_epoch=0.0307]
# Epoch 44:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0349, train_loss_epoch=0.0349]
# Epoch 45:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0325, train_loss_epoch=0.0325]
# Epoch 46:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0332, train_loss_epoch=0.0332]
# Epoch 47:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0334, train_loss_epoch=0.0334]
# Epoch 48:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0336, train_loss_epoch=0.0336]
# Epoch 49:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0339, train_loss_epoch=0.0339]
# Epoch 50:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0327, train_loss_epoch=0.0327]
# Epoch 51:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0353, train_loss_epoch=0.0353]
# Epoch 52:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.032, train_loss_epoch=0.032]
# Epoch 53:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0305, train_loss_epoch=0.0305]
# Epoch 54:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0336, train_loss_epoch=0.0336]
# Epoch 55:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0333, train_loss_epoch=0.0333]
# Epoch 56:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0316, train_loss_epoch=0.0316]
# Epoch 57:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0326, train_loss_epoch=0.0326]
# Epoch 58:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0335, train_loss_epoch=0.0335]
# Epoch 59:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0333, train_loss_epoch=0.0333]
# Epoch 60:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0289, train_loss_epoch=0.0289]
# Epoch 61:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0338, train_loss_epoch=0.0338]
# Epoch 61: 100%|██████████| 1/1 [00:00<00:00,  7.92it/s, v_num=0, train_loss_step=0.0336, train_loss_epoch=0.0336]
# Epoch 62:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0336, train_loss_epoch=0.0336]
# Epoch 63:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0345, train_loss_epoch=0.0345]
# Epoch 64:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0315, train_loss_epoch=0.0315]
# Epoch 65:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0306, train_loss_epoch=0.0306]
# Epoch 66:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.032, train_loss_epoch=0.032]
# Epoch 67:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0335, train_loss_epoch=0.0335]
# Epoch 68:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0322, train_loss_epoch=0.0322]
# Epoch 69:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.031, train_loss_epoch=0.031]
# Epoch 70:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.035, train_loss_epoch=0.035]
# Epoch 71:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0326, train_loss_epoch=0.0326]
# Epoch 72:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0319, train_loss_epoch=0.0319]
# Epoch 73:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0345, train_loss_epoch=0.0345]
# Epoch 74:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0344, train_loss_epoch=0.0344]
# Epoch 75:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0341, train_loss_epoch=0.0341]
# Epoch 76:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0339, train_loss_epoch=0.0339]
# Epoch 77:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0332, train_loss_epoch=0.0332]
# Epoch 78:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0354, train_loss_epoch=0.0354]
# Epoch 79:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0323, train_loss_epoch=0.0323]
# Epoch 79: 100%|██████████| 1/1 [00:00<00:00,  7.64it/s, v_num=0, train_loss_step=0.0323, train_loss_epoch=0.0323]
# Epoch 80:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0343, train_loss_epoch=0.0343]
# Epoch 81:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0337, train_loss_epoch=0.0337]
# Epoch 82:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0328, train_loss_epoch=0.0328]
# Epoch 83:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0338, train_loss_epoch=0.0338]
# Epoch 84:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0317, train_loss_epoch=0.0317]
# Epoch 85:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0337, train_loss_epoch=0.0337]
# Epoch 86:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0309, train_loss_epoch=0.0309]
# Epoch 87:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0328, train_loss_epoch=0.0328]
# Epoch 88:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.034, train_loss_epoch=0.034]
# Epoch 89:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0342, train_loss_epoch=0.0342]
# Epoch 90:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0354, train_loss_epoch=0.0354]
# Epoch 91:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0346, train_loss_epoch=0.0346]
# Epoch 92:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.030, train_loss_epoch=0.030]
# Epoch 93:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0327, train_loss_epoch=0.0327]
# Epoch 94:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0328, train_loss_epoch=0.0328]
# Epoch 95:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0357, train_loss_epoch=0.0357]
# Epoch 96:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0358, train_loss_epoch=0.0358]
# Epoch 97:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0315, train_loss_epoch=0.0315]
# Epoch 98:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0332, train_loss_epoch=0.0332]
# Epoch 99:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0339, train_loss_epoch=0.0339]
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00,  8.93it/s, v_num=0, train_loss_step=0.0329, train_loss_epoch=0.0339]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# (_train_tune pid=6483)
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 111.82it/s]
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00,  7.18it/s, v_num=0, train_loss_step=0.0329, train_loss_epoch=0.0329, valid_loss=0.0407]
# (_train_tune pid=6483) `Trainer.fit` stopped: `max_steps=100` reached.
# (_train_tune pid=6671) /usr/local/lib/python3.10/dist-packages/ray/tune/integration/pytorch_lightning.py:198: `ray.tune.integration.pytorch_lightning.TuneReportCallback` is deprecated. Use `ray.tune.integration.pytorch_lightning.TuneReportCheckpointCallback` instead.
# (_train_tune pid=6671) Seed set to 1
# (_train_tune pid=6671) GPU available: False, used: False
# (_train_tune pid=6671) TPU available: False, using: 0 TPU cores
# (_train_tune pid=6671) HPU available: False, using: 0 HPUs
# (_train_tune pid=6671) Missing logger folder: /tmp/ray/session_2024-06-18_05-42-21_160125_5407/artifacts/2024-06-18_05-42-31/_train_tune_2024-06-18_05-42-21/working_dirs/_train_tune_8698d_00003_3_activation=ReLU,batch_size=7,input_size=50,interpolation_mode=linear,learning_rate=0.0010,max_steps=100,_2024-06-18_05-42-32/lightning_logs
# (_train_tune pid=6671) 2024-06-18 05:44:22.507712: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (_train_tune pid=6671) 2024-06-18 05:44:22.507794: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (_train_tune pid=6671) 2024-06-18 05:44:22.509459: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (_train_tune pid=6671) 2024-06-18 05:44:22.519147: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# (_train_tune pid=6671) To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (_train_tune pid=6671) 2024-06-18 05:44:23.931574: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (_train_tune pid=6671)
# (_train_tune pid=6671)   | Name         | Type          | Params | Mode
# (_train_tune pid=6671) -------------------------------------------------------
# (_train_tune pid=6671) 0 | loss         | MAE           | 0      | train
# (_train_tune pid=6671) 1 | padder_train | ConstantPad1d | 0      | train
# (_train_tune pid=6671) 2 | scaler       | TemporalNorm  | 0      | train
# (_train_tune pid=6671) 3 | blocks       | ModuleList    | 2.5 M  | train
# (_train_tune pid=6671) -------------------------------------------------------
# (_train_tune pid=6671) 2.5 M     Trainable params
# (_train_tune pid=6671) 0         Non-trainable params
# (_train_tune pid=6671) 2.5 M     Total params
# (_train_tune pid=6671) 9.919     Total estimated model params size (MB)
# Epoch 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 1:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0389, train_loss_epoch=0.0389]
# Epoch 2:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.503, train_loss_epoch=0.503]
# Epoch 3:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0921, train_loss_epoch=0.0921]
# Epoch 4:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.173, train_loss_epoch=0.173]
# Epoch 5:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0885, train_loss_epoch=0.0885]
# Epoch 6:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0396, train_loss_epoch=0.0396]
# Epoch 7:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0501, train_loss_epoch=0.0501]
# Epoch 8:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0355, train_loss_epoch=0.0355]
# Epoch 9:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0435, train_loss_epoch=0.0435]
# Epoch 10:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0398, train_loss_epoch=0.0398]
# Epoch 11:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0349, train_loss_epoch=0.0349]
# Epoch 12:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0357, train_loss_epoch=0.0357]
# Epoch 13:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0349, train_loss_epoch=0.0349]
# Epoch 14:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0334, train_loss_epoch=0.0334]
# Epoch 15:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0349, train_loss_epoch=0.0349]
# ...
# Epoch 93:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.033, train_loss_epoch=0.033]
# Epoch 94:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0323, train_loss_epoch=0.0323]
# Epoch 95:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0332, train_loss_epoch=0.0332]
# Epoch 96:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0301, train_loss_epoch=0.0301]
# Epoch 97:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0352, train_loss_epoch=0.0352]
# Epoch 98:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0341, train_loss_epoch=0.0341]
# Epoch 99:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0319, train_loss_epoch=0.0319]
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00,  8.79it/s, v_num=0, train_loss_step=0.0333, train_loss_epoch=0.0319]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# (_train_tune pid=6671)
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 139.89it/s]
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00,  7.16it/s, v_num=0, train_loss_step=0.0333, train_loss_epoch=0.0333, valid_loss=0.0382]
# (_train_tune pid=6671) `Trainer.fit` stopped: `max_steps=100` reached.
# (_train_tune pid=6849) /usr/local/lib/python3.10/dist-packages/ray/tune/integration/pytorch_lightning.py:198: `ray.tune.integration.pytorch_lightning.TuneReportCallback` is deprecated. Use `ray.tune.integration.pytorch_lightning.TuneReportCheckpointCallback` instead.
# (_train_tune pid=6849) Seed set to 3
# (_train_tune pid=6849) GPU available: False, used: False
# (_train_tune pid=6849) TPU available: False, using: 0 TPU cores
# (_train_tune pid=6849) HPU available: False, using: 0 HPUs
# (_train_tune pid=6849) Missing logger folder: /tmp/ray/session_2024-06-18_05-42-21_160125_5407/artifacts/2024-06-18_05-42-31/_train_tune_2024-06-18_05-42-21/working_dirs/_train_tune_8698d_00004_4_activation=ReLU,batch_size=7,input_size=50,interpolation_mode=linear,learning_rate=0.0010,max_steps=100,_2024-06-18_05-42-32/lightning_logs
# (_train_tune pid=6849) 2024-06-18 05:44:49.116595: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (_train_tune pid=6849) 2024-06-18 05:44:49.116665: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (_train_tune pid=6849) 2024-06-18 05:44:49.118964: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (_train_tune pid=6849) 2024-06-18 05:44:49.134148: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# (_train_tune pid=6849) To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (_train_tune pid=6849) 2024-06-18 05:44:50.991613: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (_train_tune pid=6849)
# (_train_tune pid=6849)   | Name         | Type          | Params | Mode
# (_train_tune pid=6849) -------------------------------------------------------
# (_train_tune pid=6849) 0 | loss         | MAE           | 0      | train
# (_train_tune pid=6849) 1 | padder_train | ConstantPad1d | 0      | train
# (_train_tune pid=6849) 2 | scaler       | TemporalNorm  | 0      | train
# (_train_tune pid=6849) 3 | blocks       | ModuleList    | 2.5 M  | train
# (_train_tune pid=6849) -------------------------------------------------------
# (_train_tune pid=6849) 2.5 M     Trainable params
# (_train_tune pid=6849) 0         Non-trainable params
# (_train_tune pid=6849) 2.5 M     Total params
# (_train_tune pid=6849) 9.956     Total estimated model params size (MB)
# Epoch 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 1:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0467, train_loss_epoch=0.0467]
# Epoch 2:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.175, train_loss_epoch=0.175]
# Epoch 3:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0661, train_loss_epoch=0.0661]
# Epoch 4:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0441, train_loss_epoch=0.0441]
# Epoch 5:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0441, train_loss_epoch=0.0441]
# Epoch 6:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0413, train_loss_epoch=0.0413]
# Epoch 7:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0343, train_loss_epoch=0.0343]
# Epoch 8:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0355, train_loss_epoch=0.0355]
# Epoch 9:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0348, train_loss_epoch=0.0348]
# Epoch 10:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0344, train_loss_epoch=0.0344]
# Epoch 11:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0356, train_loss_epoch=0.0356]
# Epoch 12:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0307, train_loss_epoch=0.0307]
# Epoch 13:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0315, train_loss_epoch=0.0315]
# Epoch 14:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0355, train_loss_epoch=0.0355]
# Epoch 15:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0323, train_loss_epoch=0.0323]
# Epoch 16:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0329, train_loss_epoch=0.0329]
# Epoch 17:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0354, train_loss_epoch=0.0354]
# Epoch 18:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.034, train_loss_epoch=0.034]
# Epoch 19:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0322, train_loss_epoch=0.0322]
# Epoch 20:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0311, train_loss_epoch=0.0311]
# Epoch 21:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0313, train_loss_epoch=0.0313]
# Epoch 22:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0332, train_loss_epoch=0.0332]
# Epoch 23:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0352, train_loss_epoch=0.0352]
# Epoch 24:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0324, train_loss_epoch=0.0324]
# Epoch 25:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0362, train_loss_epoch=0.0362]
# Epoch 26:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0313, train_loss_epoch=0.0313]
# Epoch 27:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0322, train_loss_epoch=0.0322]
# Epoch 28:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0319, train_loss_epoch=0.0319]
# Epoch 29:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0339, train_loss_epoch=0.0339]
# Epoch 30:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0341, train_loss_epoch=0.0341]
# Epoch 31:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0321, train_loss_epoch=0.0321]
# Epoch 32:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0329, train_loss_epoch=0.0329]
# Epoch 33:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0324, train_loss_epoch=0.0324]
# Epoch 34:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0328, train_loss_epoch=0.0328]
# Epoch 35:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0316, train_loss_epoch=0.0316]
# Epoch 36:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0338, train_loss_epoch=0.0338]
# Epoch 37:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0317, train_loss_epoch=0.0317]
# Epoch 38:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0359, train_loss_epoch=0.0359]
# Epoch 39:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0339, train_loss_epoch=0.0339]
# Epoch 40:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0311, train_loss_epoch=0.0311]
# Epoch 41:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0332, train_loss_epoch=0.0332]
# Epoch 42:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0341, train_loss_epoch=0.0341]
# Epoch 43:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0304, train_loss_epoch=0.0304]
# Epoch 44:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0349, train_loss_epoch=0.0349]
# Epoch 44: 100%|██████████| 1/1 [00:00<00:00,  8.95it/s, v_num=0, train_loss_step=0.0324, train_loss_epoch=0.0324]
# Epoch 45:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0324, train_loss_epoch=0.0324]
# Epoch 46:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0332, train_loss_epoch=0.0332]
# Epoch 47:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0332, train_loss_epoch=0.0332]
# Epoch 48:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0336, train_loss_epoch=0.0336]
# Epoch 49:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0338, train_loss_epoch=0.0338]
# Epoch 50:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0326, train_loss_epoch=0.0326]
# Epoch 51:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0348, train_loss_epoch=0.0348]
# Epoch 52:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0319, train_loss_epoch=0.0319]
# Epoch 53:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0303, train_loss_epoch=0.0303]
# Epoch 54:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0334, train_loss_epoch=0.0334]
# Epoch 55:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.033, train_loss_epoch=0.033]
# Epoch 55: 100%|██████████| 1/1 [00:00<00:00,  8.81it/s, v_num=0, train_loss_step=0.0312, train_loss_epoch=0.033]
# Epoch 55: 100%|██████████| 1/1 [00:00<00:00,  8.56it/s, v_num=0, train_loss_step=0.0312, train_loss_epoch=0.0312]
# Epoch 56:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0312, train_loss_epoch=0.0312]
# Epoch 57:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0324, train_loss_epoch=0.0324]
# Epoch 58:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0333, train_loss_epoch=0.0333]
# Epoch 59:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0333, train_loss_epoch=0.0333]
# Epoch 60:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0285, train_loss_epoch=0.0285]
# Epoch 61:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0334, train_loss_epoch=0.0334]
# Epoch 62:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0334, train_loss_epoch=0.0334]
# Epoch 63:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0343, train_loss_epoch=0.0343]
# Epoch 64:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0312, train_loss_epoch=0.0312]
# Epoch 65:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0305, train_loss_epoch=0.0305]
# Epoch 66:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0317, train_loss_epoch=0.0317]
# Epoch 67:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0331, train_loss_epoch=0.0331]
# Epoch 68:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.032, train_loss_epoch=0.032]
# Epoch 69:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0308, train_loss_epoch=0.0308]
# Epoch 70:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0347, train_loss_epoch=0.0347]
# Epoch 71:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0323, train_loss_epoch=0.0323]
# Epoch 72:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0315, train_loss_epoch=0.0315]
# Epoch 73:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.034, train_loss_epoch=0.034]
# Epoch 74:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0338, train_loss_epoch=0.0338]
# Epoch 75:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0336, train_loss_epoch=0.0336]
# Epoch 76:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0334, train_loss_epoch=0.0334]
# Epoch 77:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0328, train_loss_epoch=0.0328]
# Epoch 78:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0348, train_loss_epoch=0.0348]
# Epoch 79:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0319, train_loss_epoch=0.0319]
# Epoch 80:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0341, train_loss_epoch=0.0341]
# Epoch 81:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0333, train_loss_epoch=0.0333]
# Epoch 82:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0324, train_loss_epoch=0.0324]
# Epoch 83:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0337, train_loss_epoch=0.0337]
# Epoch 84:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0315, train_loss_epoch=0.0315]
# Epoch 85:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0335, train_loss_epoch=0.0335]
# Epoch 86:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0307, train_loss_epoch=0.0307]
# Epoch 87:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0323, train_loss_epoch=0.0323]
# Epoch 88:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0338, train_loss_epoch=0.0338]
# Epoch 89:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0337, train_loss_epoch=0.0337]
# Epoch 90:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.035, train_loss_epoch=0.035]
# Epoch 91:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.034, train_loss_epoch=0.034]
# Epoch 92:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0294, train_loss_epoch=0.0294]
# Epoch 93:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0324, train_loss_epoch=0.0324]
# Epoch 94:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0323, train_loss_epoch=0.0323]
# Epoch 95:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0351, train_loss_epoch=0.0351]
# Epoch 96:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0348, train_loss_epoch=0.0348]
# Epoch 97:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0313, train_loss_epoch=0.0313]
# Epoch 98:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0324, train_loss_epoch=0.0324]
# Epoch 99:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0333, train_loss_epoch=0.0333]
# 2024-06-18 05:45:06,343	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/root/ray_results/_train_tune_2024-06-18_05-42-21' in 0.0089s.
# INFO:lightning_fabric.utilities.seed:Seed set to 1
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00,  8.93it/s, v_num=0, train_loss_step=0.0323, train_loss_epoch=0.0333]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 133.46it/s]
#
# (_train_tune pid=6849)
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00,  7.05it/s, v_num=0, train_loss_step=0.0323, train_loss_epoch=0.0323, valid_loss=0.0426]
# (_train_tune pid=6849) `Trainer.fit` stopped: `max_steps=100` reached.
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# AutoNHITS

# %%
# best params
model.results.get_best_result().config
# Out:
# {'learning_rate': 0.001,
#  'max_steps': 100,
#  'input_size': 50,
#  'batch_size': 7,
#  'windows_batch_size': 256,
#  'n_pool_kernel_size': [16, 8, 1],
#  'n_freq_downsample': [168, 24, 1],
#  'activation': 'ReLU',
#  'n_blocks': [1, 1, 1],
#  'mlp_units': [[512, 512], [512, 512], [512, 512]],
#  'interpolation_mode': 'linear',
#  'val_check_steps': 100,
#  'random_seed': 1,
#  'h': 10,
#  'loss': MAE(),
#  'valid_loss': MAE()}

# %% [markdown]
# ### Predict

# %%
import time

def predict_and_update(model, traindata, Y_train_df, predict_range, values_to_add=1, future=False):
    predictions = []
    new_Y_train_df = Y_train_df.copy()

    steps = predict_range//values_to_add + int(predict_range%values_to_add!=0)
    print(steps)

    start_time = time.time()

    for i in range(steps):
        y_hat = model.predict(dataset=traindata)
        y_hat_value = y_hat.flatten()
        predictions.extend(y_hat_value[:values_to_add])

        if future:
            next_values = []
            last_date = new_Y_train_df['ds'].iloc[-1]
            for j in range(values_to_add):
                next_value = {
                    'unique_id': new_Y_train_df['unique_id'].iloc[-1],
                    'ds': last_date + pd.Timedelta(days=j+1),
                    'y': y_hat_value[j % len(y_hat_value)]
                }
                next_values.append(next_value)
            next_df = pd.DataFrame(next_values)
        else:
            next_value = Y_test_df.iloc[i:i+values_to_add]
            next_df = next_value.reset_index(drop=True)

        new_Y_train_df = pd.concat([new_Y_train_df, next_df]).iloc[values_to_add:].reset_index(drop=True)
        traindata, *_ = TimeSeriesDataset.from_df(df=new_Y_train_df)

    execution_time = time.time() - start_time

    return predictions[:predict_range], execution_time

# %%
# %%capture
traindata, *_ = TimeSeriesDataset.from_df(df = Y_train_df)
predict_test, execution_time_test = predict_and_update(
                                                      model=model,
                                                      traindata=traindata,
                                                      Y_train_df=Y_train_df,
                                                      predict_range=test_size,
                                                      # values_to_add=5,
                                                      # future=True
                                                      )

# %%
# %%capture
traindata, *_ = TimeSeriesDataset.from_df(df = df)
predict_future, execution_time_future = predict_and_update(
                                                          model=model,
                                                          traindata=traindata,
                                                          Y_train_df=Y_train_df,
                                                          predict_range=DAY_TO_PREDICT,
                                                          # values_to_add=5,
                                                          future=True
                                                          )

# %%
print(f'Test size: {len(predict_test)}, Execution time: {execution_time_test}')
print(f'Future size: {len(predict_future)}, Execution time: {execution_time_future}')
# Out:
# Test size: 138, Execution time: 35.6482789516449
# Future size: 90, Execution time: 21.183917760849

# %% [markdown]
# ### Evaluate accuracy

# %%
def evaluate_accuracy(y_test, y_pred):
    test_rmse = np.sqrt(np.mean((y_pred - y_test)**2))
    RMSE = f'Testing RMSE: {test_rmse}'

    test_mape = np.mean(np.abs(y_pred - y_test)/np.abs(y_test))
    MAPE = f'Testing MAPE: {test_mape}'

    test_mae = np.mean(abs(y_pred - y_test))
    MAE = f'Testing MAE: {test_mae}'

    #print
    max_length = max(len(RMSE), len(MAPE), len(MAE))

    print('Evaluate Accuracy')
    print('=' * max_length)
    print(RMSE)
    print(MAPE)
    print(MAE)
    print('=' * max_length)

# %%
def inverse_data(Y_train_df, Y_test_df, predict_test, predict_future):
  Y_train_df_close = scaler.inverse_transform(Y_train_df[['y']])
  Y_test_df_close = scaler.inverse_transform(Y_test_df[['y']])

  predict_test = np.array(predict_test)
  predict_future = np.array(predict_future)

  predict_test = scaler.inverse_transform(predict_test.reshape(-1, 1))
  predict_future = scaler.inverse_transform(predict_future.reshape(-1, 1))

  return Y_train_df_close, Y_test_df_close, predict_test.flatten(), predict_future.flatten()

# %%
 y_train, y_test, predict_test, predict_future = inverse_data(Y_train_df, Y_test_df, predict_test, predict_future)

# %%
evaluate_accuracy(y_test, predict_test)
# Out:
# Evaluate Accuracy
# =================================
# Testing RMSE: 5998.809659192384
# Testing MAPE: 0.10026292379760637
# Testing MAE: 4663.715224081207
# =================================

# %% [markdown]
# ## Visualize result

# %%
import matplotlib.pyplot as plt

#plt.rcParams["axes.grid"]=True
plt.rcParams['font.family'] = 'serif'
plt.rcParams["figure.figsize"] = (12,8)

# %%
colors = plt.get_cmap('tab10').colors

# %%
def make_all_result_plot(data):
  (train_data_index, y_train, test_data_index, y_test, predict_test, predict_future_data_index, predict_future) = data

  figname = f'{DATASET_LABEL} {TRAIN_TEST_LABEL}'
  plt.title(figname)
  plt.xlabel('Index')
  plt.ylabel('Price')

  plt.plot(train_data_index, y_train, color=colors[0])

  plt.plot(test_data_index, y_test, color=colors[1])

  predict_test_data_index = test_data_index
  plt.plot(predict_test_data_index, predict_test, color=colors[2])

  plt.plot(predict_future_data_index[0:30], predict_future[0:30], color=colors[3])
  plt.plot(predict_future_data_index[30:60], predict_future[30:60], color=colors[4])
  plt.plot(predict_future_data_index[60:90], predict_future[60:90], color=colors[5])

  plt.legend(['Train','Test','PredictTest','Predict30Days','Predict60Days','Predict90Days'])
  plt.show()

# %%
def make_future_result_plot(data):
  (predict_future_data_index, predict_future) = data

  day_label = 'Days' if DAY_TO_PREDICT > 1 else 'Day'
  figname = f'{DATASET_LABEL} - Next {DAY_TO_PREDICT} {day_label}'
  plt.title(figname)
  plt.xlabel('Index')
  plt.ylabel('Price')

  plt.plot(predict_future_data_index[0:30], predict_future[0:30], color=colors[0])
  plt.plot(predict_future_data_index[30:60], predict_future[30:60], color=colors[1])
  plt.plot(predict_future_data_index[60:90], predict_future[60:90], color=colors[2])
  plt.show()

# %%
train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
predict_future_data_index = pd.RangeIndex(start=train_size+test_size, stop=train_size+test_size+len(predict_future), step=1)

print('All result plot')
make_all_result_plot((train_data_index, y_train, test_data_index, y_test, predict_test, predict_future_data_index, predict_future))
# Out:
# All result plot

# %%
predict_future_data_index = pd.RangeIndex(start=0, stop=len(predict_future), step=1)

print('Next 90 days plot')
make_future_result_plot((predict_future_data_index, predict_future))
# Out:
# Next 90 days plot
